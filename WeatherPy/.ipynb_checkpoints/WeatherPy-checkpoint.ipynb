# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#set up DF for response 

city_weatherDF = pd.DataFrame({'City': cities, 'Cloudiness' : "",  'Date': "", 'Humidity' : "", 'Lat' : "",
                              'Lng' : "", 'Max Temp' : "", 'Windspeed': ""})

#variables for response
record_number = 1
set_number = 1

#Setting Base URL for Call
base_url = 'http://api.openweathermap.org/data/2.5/weather?units=imperial&q=' 


#API Call 
print('''
---------------------------
Beginning Data Retrieval
---------------------------''')

for index, row in city_weatherDF.iterrows():
    #Query Url
    weather_query = base_url + row['City'] + '&APPID=' + weather_api_key
    
# #Response Call
    response = requests.get(weather_query).json()
    
    #Exception error for City Not Found .. 
    try: 
        print(f'Processing Weather Data for Record {record_number} of Set {set_number} | {response["name"]}')
        
        #Input data into the dataframe
        city_weatherDF.loc[index, 'Cloudiness'] = response['clouds']['all']
        city_weatherDF.loc[index, 'Date'] = response['dt']
        city_weatherDF.loc[index, 'Humidity'] = response['main']['humidity']
        city_weatherDF.loc[index, 'Lat'] = response['coord']['lat']
        city_weatherDF.loc[index, 'Lng'] = response['coord']['lon']
        city_weatherDF.loc[index, 'Max Temp'] = response['main']['temp_max']
        city_weatherDF.loc[index, 'Windspeed'] = response['wind']['speed']
        
        #Increase the record count
        record_number += 1
        
    except (KeyError, IndexError):
        print("City not found....Skipping............")
        
    #API Limit
    if record_number == 101:
        set_number += 1
        record_number = 1
        time.sleep(15)

        print('''
-----------------------------
Data Retrieval Complete
-----------------------------''')
# Out:
# ---------------------------
# Beginning Data Retrieval
# ---------------------------
# Processing Weather Data for Record 1 of Set 1 | Geraldton
# City not found....Skipping............
# Processing Weather Data for Record 2 of Set 1 | São Filipe
# Processing Weather Data for Record 3 of Set 1 | Mataura
# Processing Weather Data for Record 4 of Set 1 | Bumbuna
# Processing Weather Data for Record 5 of Set 1 | Bluff
# Processing Weather Data for Record 6 of Set 1 | Hong Kong
# Processing Weather Data for Record 7 of Set 1 | Kaniama
# Processing Weather Data for Record 8 of Set 1 | Klyuchi
# Processing Weather Data for Record 9 of Set 1 | Oddur
# Processing Weather Data for Record 10 of Set 1 | Jamestown
# Processing Weather Data for Record 11 of Set 1 | New Norfolk
# Processing Weather Data for Record 12 of Set 1 | Cheyenne
# Processing Weather Data for Record 13 of Set 1 | Hermanus
# Processing Weather Data for Record 14 of Set 1 | Rikitea
# Processing Weather Data for Record 15 of Set 1 | Along
# Processing Weather Data for Record 16 of Set 1 | Ahipara
# Processing Weather Data for Record 17 of Set 1 | Düzce
# Processing Weather Data for Record 18 of Set 1 | Dikson
# Processing Weather Data for Record 19 of Set 1 | Ostrovnoy
# Processing Weather Data for Record 20 of Set 1 | Beaverlodge
# City not found....Skipping............
# Processing Weather Data for Record 21 of Set 1 | Puerto Ayora
# Processing Weather Data for Record 22 of Set 1 | Dingle
# Processing Weather Data for Record 23 of Set 1 | Coahuayana Viejo
# Processing Weather Data for Record 24 of Set 1 | Filingué
# Processing Weather Data for Record 25 of Set 1 | Khatanga
# Processing Weather Data for Record 26 of Set 1 | Arraial do Cabo
# Processing Weather Data for Record 27 of Set 1 | Labuhan
# Processing Weather Data for Record 28 of Set 1 | Ambilobe
# Processing Weather Data for Record 29 of Set 1 | Esmeraldas
# Processing Weather Data for Record 30 of Set 1 | Norman Wells
# Processing Weather Data for Record 31 of Set 1 | Caucaia
# Processing Weather Data for Record 32 of Set 1 | Ushuaia
# Processing Weather Data for Record 33 of Set 1 | Wagar
# Processing Weather Data for Record 34 of Set 1 | Punta Arenas
# Processing Weather Data for Record 35 of Set 1 | Tevaitoa
# Processing Weather Data for Record 36 of Set 1 | Rincon
# Processing Weather Data for Record 37 of Set 1 | Abbeville
# Processing Weather Data for Record 38 of Set 1 | Vakhrushev
# Processing Weather Data for Record 39 of Set 1 | Ruidoso
# Processing Weather Data for Record 40 of Set 1 | Camaná
# Processing Weather Data for Record 41 of Set 1 | Thompson
# Processing Weather Data for Record 42 of Set 1 | Chu
# Processing Weather Data for Record 43 of Set 1 | Tasiilaq
# Processing Weather Data for Record 44 of Set 1 | Yellowknife
# Processing Weather Data for Record 45 of Set 1 | Upernavik
# Processing Weather Data for Record 46 of Set 1 | Santa Cruz de la Sierra
# Processing Weather Data for Record 47 of Set 1 | Severo-Kuril'sk
# Processing Weather Data for Record 48 of Set 1 | Polson
# City not found....Skipping............
# City not found....Skipping............
# Processing Weather Data for Record 49 of Set 1 | Albany
# Processing Weather Data for Record 50 of Set 1 | Hobart
# Processing Weather Data for Record 51 of Set 1 | Kapaa
# Processing Weather Data for Record 52 of Set 1 | Srednekolymsk
# Processing Weather Data for Record 53 of Set 1 | La Ronge
# Processing Weather Data for Record 54 of Set 1 | Hilo
# Processing Weather Data for Record 55 of Set 1 | Portland
# Processing Weather Data for Record 56 of Set 1 | Pisco
# Processing Weather Data for Record 57 of Set 1 | Meulaboh
# Processing Weather Data for Record 58 of Set 1 | Manokwari
# Processing Weather Data for Record 59 of Set 1 | Bogale
# Processing Weather Data for Record 60 of Set 1 | Bredasdorp
# City not found....Skipping............
# Processing Weather Data for Record 61 of Set 1 | Hithadhoo
# Processing Weather Data for Record 62 of Set 1 | Klaksvík
# Processing Weather Data for Record 63 of Set 1 | Saint George
# Processing Weather Data for Record 64 of Set 1 | Edd
# Processing Weather Data for Record 65 of Set 1 | Butaritari
# Processing Weather Data for Record 66 of Set 1 | Province of Mantua
# Processing Weather Data for Record 67 of Set 1 | Padang
# Processing Weather Data for Record 68 of Set 1 | Cedral
# Processing Weather Data for Record 69 of Set 1 | Belyy Gorodok
# Processing Weather Data for Record 70 of Set 1 | Kieta
# Processing Weather Data for Record 71 of Set 1 | Mossamedes
# Processing Weather Data for Record 72 of Set 1 | Tiksi
# Processing Weather Data for Record 73 of Set 1 | Port Alfred
# Processing Weather Data for Record 74 of Set 1 | Grand Gaube
# Processing Weather Data for Record 75 of Set 1 | Cape Town
# Processing Weather Data for Record 76 of Set 1 | Vaini
# Processing Weather Data for Record 77 of Set 1 | Kindu
# Processing Weather Data for Record 78 of Set 1 | Airai
# Processing Weather Data for Record 79 of Set 1 | Tuktoyaktuk
# Processing Weather Data for Record 80 of Set 1 | Saint-Philippe
# Processing Weather Data for Record 81 of Set 1 | Busselton
# Processing Weather Data for Record 82 of Set 1 | Tarko-Sale
# Processing Weather Data for Record 83 of Set 1 | Qaanaaq
# Processing Weather Data for Record 84 of Set 1 | Bethel
# Processing Weather Data for Record 85 of Set 1 | Huarmey
# Processing Weather Data for Record 86 of Set 1 | Todos Santos
# Processing Weather Data for Record 87 of Set 1 | East London
# Processing Weather Data for Record 88 of Set 1 | Lüderitz
# Processing Weather Data for Record 89 of Set 1 | Iqaluit
# Processing Weather Data for Record 90 of Set 1 | Carlyle
# City not found....Skipping............
# Processing Weather Data for Record 91 of Set 1 | Lebu
# Processing Weather Data for Record 92 of Set 1 | El Alto
# Processing Weather Data for Record 93 of Set 1 | Atuona
# Processing Weather Data for Record 94 of Set 1 | Burnie
# Processing Weather Data for Record 95 of Set 1 | Port Lincoln
# Processing Weather Data for Record 96 of Set 1 | Bambous Virieux
# Processing Weather Data for Record 97 of Set 1 | San Cristobal
# Processing Weather Data for Record 98 of Set 1 | Pandan Niog
# Processing Weather Data for Record 99 of Set 1 | Nouakchott
# Processing Weather Data for Record 100 of Set 1 | La Rioja
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Weather Data for Record 1 of Set 2 | Örnsköldsvik
# Processing Weather Data for Record 2 of Set 2 | Kupang
# Processing Weather Data for Record 3 of Set 2 | Gerāsh
# Processing Weather Data for Record 4 of Set 2 | Alofi
# Processing Weather Data for Record 5 of Set 2 | Ordzhonīkīdze
# City not found....Skipping............
# Processing Weather Data for Record 6 of Set 2 | Westport
# Processing Weather Data for Record 7 of Set 2 | Salinópolis
# Processing Weather Data for Record 8 of Set 2 | Atar
# Processing Weather Data for Record 9 of Set 2 | Chokurdakh
# Processing Weather Data for Record 10 of Set 2 | Hofn
# Processing Weather Data for Record 11 of Set 2 | Carnarvon
# Processing Weather Data for Record 12 of Set 2 | Haines Junction
# Processing Weather Data for Record 13 of Set 2 | Mahébourg
# Processing Weather Data for Record 14 of Set 2 | Fallon
# Processing Weather Data for Record 15 of Set 2 | Laredo
# Processing Weather Data for Record 16 of Set 2 | Avarua
# Processing Weather Data for Record 17 of Set 2 | Palmer
# City not found....Skipping............
# Processing Weather Data for Record 18 of Set 2 | Fairview
# City not found....Skipping............
# Processing Weather Data for Record 19 of Set 2 | Barrow
# City not found....Skipping............
# Processing Weather Data for Record 20 of Set 2 | Tual
# Processing Weather Data for Record 21 of Set 2 | Castro
# Processing Weather Data for Record 22 of Set 2 | Santa Cruz del Norte
# Processing Weather Data for Record 23 of Set 2 | Agüimes
# Processing Weather Data for Record 24 of Set 2 | Richards Bay
# Processing Weather Data for Record 25 of Set 2 | Bāndarban
# Processing Weather Data for Record 26 of Set 2 | Lagoa
# Processing Weather Data for Record 27 of Set 2 | Rocha
# City not found....Skipping............
# Processing Weather Data for Record 28 of Set 2 | Vila
# City not found....Skipping............
# Processing Weather Data for Record 29 of Set 2 | Lusambo
# Processing Weather Data for Record 30 of Set 2 | Pundaguitan
# Processing Weather Data for Record 31 of Set 2 | Vasto
# Processing Weather Data for Record 32 of Set 2 | Yabēlo
# Processing Weather Data for Record 33 of Set 2 | Acapulco de Juárez
# Processing Weather Data for Record 34 of Set 2 | Nāthdwāra
# Processing Weather Data for Record 35 of Set 2 | Nikolskoye
# Processing Weather Data for Record 36 of Set 2 | Avera
# Processing Weather Data for Record 37 of Set 2 | Constitución
# Processing Weather Data for Record 38 of Set 2 | Egvekinot
# Processing Weather Data for Record 39 of Set 2 | Bay-Khaak
# Processing Weather Data for Record 40 of Set 2 | São João da Barra
# Processing Weather Data for Record 41 of Set 2 | Umluj
# Processing Weather Data for Record 42 of Set 2 | Port Elizabeth
# Processing Weather Data for Record 43 of Set 2 | Caravelas
# Processing Weather Data for Record 44 of Set 2 | Yar-Sale
# Processing Weather Data for Record 45 of Set 2 | Kandava
# Processing Weather Data for Record 46 of Set 2 | Mahrīz
# Processing Weather Data for Record 47 of Set 2 | Coyhaique
# Processing Weather Data for Record 48 of Set 2 | Chui
# Processing Weather Data for Record 49 of Set 2 | Mar del Plata
# Processing Weather Data for Record 50 of Set 2 | Waingapu
# Processing Weather Data for Record 51 of Set 2 | Casablanca
# Processing Weather Data for Record 52 of Set 2 | Saint-Augustin
# Processing Weather Data for Record 53 of Set 2 | Yertarskiy
# City not found....Skipping............
# Processing Weather Data for Record 54 of Set 2 | Caramay
# Processing Weather Data for Record 55 of Set 2 | George Town
# Processing Weather Data for Record 56 of Set 2 | Cidreira
# City not found....Skipping............
# Processing Weather Data for Record 57 of Set 2 | Mehamn
# Processing Weather Data for Record 58 of Set 2 | Kaitangata
# Processing Weather Data for Record 59 of Set 2 | Igarka
# Processing Weather Data for Record 60 of Set 2 | Codrington
# Processing Weather Data for Record 61 of Set 2 | Palu
# Processing Weather Data for Record 62 of Set 2 | Naze
# Processing Weather Data for Record 63 of Set 2 | Jardim
# Processing Weather Data for Record 64 of Set 2 | Rome
# Processing Weather Data for Record 65 of Set 2 | Vardø
# Processing Weather Data for Record 66 of Set 2 | São Joaquim
# Processing Weather Data for Record 67 of Set 2 | Fort Nelson
# Processing Weather Data for Record 68 of Set 2 | Birao
# City not found....Skipping............
# Processing Weather Data for Record 69 of Set 2 | Skjervøy
# Processing Weather Data for Record 70 of Set 2 | Nabire
# Processing Weather Data for Record 71 of Set 2 | Saskylakh
# Processing Weather Data for Record 72 of Set 2 | Mogadishu
# Processing Weather Data for Record 73 of Set 2 | Ambunti
# Processing Weather Data for Record 74 of Set 2 | El Fuerte
# Processing Weather Data for Record 75 of Set 2 | Līsakovsk
# Processing Weather Data for Record 76 of Set 2 | Dingli
# Processing Weather Data for Record 77 of Set 2 | Saint Paul Harbor
# Processing Weather Data for Record 78 of Set 2 | Dumas
# Processing Weather Data for Record 79 of Set 2 | Darnah
# Processing Weather Data for Record 80 of Set 2 | Carballo
# Processing Weather Data for Record 81 of Set 2 | Peterhead
# Processing Weather Data for Record 82 of Set 2 | Bengkulu
# Processing Weather Data for Record 83 of Set 2 | Souillac
# Processing Weather Data for Record 84 of Set 2 | Kiryat Gat
# Processing Weather Data for Record 85 of Set 2 | Buala
# City not found....Skipping............
# Processing Weather Data for Record 86 of Set 2 | Mount Isa
# Processing Weather Data for Record 87 of Set 2 | Kerecsend
# City not found....Skipping............
# Processing Weather Data for Record 88 of Set 2 | Itarema
# Processing Weather Data for Record 89 of Set 2 | Coquimbo
# Processing Weather Data for Record 90 of Set 2 | Mingguang
# Processing Weather Data for Record 91 of Set 2 | Nanortalik
# Processing Weather Data for Record 92 of Set 2 | Cherskiy
# Processing Weather Data for Record 93 of Set 2 | Fairbanks
# Processing Weather Data for Record 94 of Set 2 | Pangody
# Processing Weather Data for Record 95 of Set 2 | Quang Ngai
# Processing Weather Data for Record 96 of Set 2 | Jiuquan
# Processing Weather Data for Record 97 of Set 2 | Ponta do Sol
# Processing Weather Data for Record 98 of Set 2 | Faya
# Processing Weather Data for Record 99 of Set 2 | Benjamin Constant
# Processing Weather Data for Record 100 of Set 2 | Imbituba
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Weather Data for Record 1 of Set 3 | Strezhevoy
# City not found....Skipping............
# Processing Weather Data for Record 2 of Set 3 | Kazygurt
# Processing Weather Data for Record 3 of Set 3 | Port-Gentil
# Processing Weather Data for Record 4 of Set 3 | Darhan
# Processing Weather Data for Record 5 of Set 3 | Takoradze
# Processing Weather Data for Record 6 of Set 3 | Hastings
# Processing Weather Data for Record 7 of Set 3 | Norfolk
# Processing Weather Data for Record 8 of Set 3 | Jalu
# Processing Weather Data for Record 9 of Set 3 | Paita
# Processing Weather Data for Record 10 of Set 3 | Provideniya
# Processing Weather Data for Record 11 of Set 3 | Marapanim
# Processing Weather Data for Record 12 of Set 3 | Nemuro
# Processing Weather Data for Record 13 of Set 3 | Saint Anthony
# Processing Weather Data for Record 14 of Set 3 | Taltal
# Processing Weather Data for Record 15 of Set 3 | Yulara
# Processing Weather Data for Record 16 of Set 3 | Longyearbyen
# Processing Weather Data for Record 17 of Set 3 | Polignano a Mare
# Processing Weather Data for Record 18 of Set 3 | Vila Franca do Campo
# Processing Weather Data for Record 19 of Set 3 | Aksarka
# Processing Weather Data for Record 20 of Set 3 | Arrifes
# Processing Weather Data for Record 21 of Set 3 | Grindavik
# Processing Weather Data for Record 22 of Set 3 | Erenhot
# Processing Weather Data for Record 23 of Set 3 | Salalah
# Processing Weather Data for Record 24 of Set 3 | Newport
# Processing Weather Data for Record 25 of Set 3 | Benton Harbor
# Processing Weather Data for Record 26 of Set 3 | Sorong
# Processing Weather Data for Record 27 of Set 3 | Fortuna
# Processing Weather Data for Record 28 of Set 3 | Angoche
# Processing Weather Data for Record 29 of Set 3 | Yaan
# Processing Weather Data for Record 30 of Set 3 | Hambantota
# Processing Weather Data for Record 31 of Set 3 | Faanui
# City not found....Skipping............
# City not found....Skipping............
# Processing Weather Data for Record 32 of Set 3 | Hasaki
# Processing Weather Data for Record 33 of Set 3 | Deputatsky
# Processing Weather Data for Record 34 of Set 3 | Adrar
# Processing Weather Data for Record 35 of Set 3 | Rawson
# Processing Weather Data for Record 36 of Set 3 | Bonavista
# Processing Weather Data for Record 37 of Set 3 | Wum
# Processing Weather Data for Record 38 of Set 3 | Cayenne
# City not found....Skipping............
# Processing Weather Data for Record 39 of Set 3 | Marzuq
# Processing Weather Data for Record 40 of Set 3 | Mago
# Processing Weather Data for Record 41 of Set 3 | Paamiut
# Processing Weather Data for Record 42 of Set 3 | Saldanha
# Processing Weather Data for Record 43 of Set 3 | Mae Ramat
# City not found....Skipping............
# Processing Weather Data for Record 44 of Set 3 | Goderich
# Processing Weather Data for Record 45 of Set 3 | Socorro
# Processing Weather Data for Record 46 of Set 3 | Wawa
# Processing Weather Data for Record 47 of Set 3 | Karla
# Processing Weather Data for Record 48 of Set 3 | Ribeira Grande
# Processing Weather Data for Record 49 of Set 3 | San Juan
# Processing Weather Data for Record 50 of Set 3 | General Pico
# Processing Weather Data for Record 51 of Set 3 | Sibiti
# Processing Weather Data for Record 52 of Set 3 | Narsaq
# City not found....Skipping............
# Processing Weather Data for Record 53 of Set 3 | Magán
# Processing Weather Data for Record 54 of Set 3 | Pangoa
# Processing Weather Data for Record 55 of Set 3 | Yatou
# Processing Weather Data for Record 56 of Set 3 | Banjar
# Processing Weather Data for Record 57 of Set 3 | Evensk
# Processing Weather Data for Record 58 of Set 3 | Guerrero Negro
# Processing Weather Data for Record 59 of Set 3 | Shimoda
# City not found....Skipping............
# Processing Weather Data for Record 60 of Set 3 | Lukovetskiy
# Processing Weather Data for Record 61 of Set 3 | Aklavik
# Processing Weather Data for Record 62 of Set 3 | Vostok
# Processing Weather Data for Record 63 of Set 3 | Qaryat Sulūq
# Processing Weather Data for Record 64 of Set 3 | Guiratinga
# Processing Weather Data for Record 65 of Set 3 | Mponela
# Processing Weather Data for Record 66 of Set 3 | Azovo
# Processing Weather Data for Record 67 of Set 3 | Arys
# Processing Weather Data for Record 68 of Set 3 | Evanston
# Processing Weather Data for Record 69 of Set 3 | Kruisfontein
# Processing Weather Data for Record 70 of Set 3 | Byron Bay
# Processing Weather Data for Record 71 of Set 3 | Arona
# Processing Weather Data for Record 72 of Set 3 | Panabá
# Processing Weather Data for Record 73 of Set 3 | Launceston
# Processing Weather Data for Record 74 of Set 3 | Sumbe
# Processing Weather Data for Record 75 of Set 3 | Astoria
# Processing Weather Data for Record 76 of Set 3 | Katsuura
# Processing Weather Data for Record 77 of Set 3 | Vilhena
# Processing Weather Data for Record 78 of Set 3 | Kismayo
# Processing Weather Data for Record 79 of Set 3 | Lompoc
# Processing Weather Data for Record 80 of Set 3 | Shache
# Processing Weather Data for Record 81 of Set 3 | Gillette
# Processing Weather Data for Record 82 of Set 3 | Gisborne
# Processing Weather Data for Record 83 of Set 3 | Brønnøysund
# Processing Weather Data for Record 84 of Set 3 | Turukhansk
# City not found....Skipping............
# Processing Weather Data for Record 85 of Set 3 | Kharovsk
# Processing Weather Data for Record 86 of Set 3 | Winburg
# Processing Weather Data for Record 87 of Set 3 | Bedēsa
# Processing Weather Data for Record 88 of Set 3 | Fügen
# Processing Weather Data for Record 89 of Set 3 | Suba
# Processing Weather Data for Record 90 of Set 3 | Beidao
# Processing Weather Data for Record 91 of Set 3 | Matara
# Processing Weather Data for Record 92 of Set 3 | Sitka
# Processing Weather Data for Record 93 of Set 3 | Sittwe
# Processing Weather Data for Record 94 of Set 3 | Sangar
# Processing Weather Data for Record 95 of Set 3 | Olafsvik
# Processing Weather Data for Record 96 of Set 3 | Esperance
# Processing Weather Data for Record 97 of Set 3 | Alenquer
# Processing Weather Data for Record 98 of Set 3 | Grafton
# Processing Weather Data for Record 99 of Set 3 | Bubaque
# Processing Weather Data for Record 100 of Set 3 | Weyburn
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Weather Data for Record 1 of Set 4 | Samaná
# Processing Weather Data for Record 2 of Set 4 | Siniscola
# Processing Weather Data for Record 3 of Set 4 | Malmyzh
# Processing Weather Data for Record 4 of Set 4 | Fairmont
# Processing Weather Data for Record 5 of Set 4 | Clacton-on-Sea
# City not found....Skipping............
# Processing Weather Data for Record 6 of Set 4 | Kattivākkam
# Processing Weather Data for Record 7 of Set 4 | Manjakandriana
# Processing Weather Data for Record 8 of Set 4 | Prince Albert
# Processing Weather Data for Record 9 of Set 4 | Humlebæk
# Processing Weather Data for Record 10 of Set 4 | Sakakah
# Processing Weather Data for Record 11 of Set 4 | Flinders
# Processing Weather Data for Record 12 of Set 4 | Bereket
# Processing Weather Data for Record 13 of Set 4 | La Sarre
# Processing Weather Data for Record 14 of Set 4 | Lesozavodsk
# Processing Weather Data for Record 15 of Set 4 | Chernyshevskiy
# Processing Weather Data for Record 16 of Set 4 | Port-Cartier
# Processing Weather Data for Record 17 of Set 4 | Ilulissat
# Processing Weather Data for Record 18 of Set 4 | Mezen'
# City not found....Skipping............
# Processing Weather Data for Record 19 of Set 4 | Hirara
# Processing Weather Data for Record 20 of Set 4 | Plettenberg Bay
# Processing Weather Data for Record 21 of Set 4 | Cabra
# Processing Weather Data for Record 22 of Set 4 | Nambucca Heads
# Processing Weather Data for Record 23 of Set 4 | Prome
# Processing Weather Data for Record 24 of Set 4 | Poum
# City not found....Skipping............
# Processing Weather Data for Record 25 of Set 4 | Christchurch
# Processing Weather Data for Record 26 of Set 4 | Gijang
# City not found....Skipping............
# Processing Weather Data for Record 27 of Set 4 | Popondetta
# Processing Weather Data for Record 28 of Set 4 | Mīnāb
# Processing Weather Data for Record 29 of Set 4 | Port Hedland
# Processing Weather Data for Record 30 of Set 4 | Saint-Leu
# Processing Weather Data for Record 31 of Set 4 | Urcos
# Processing Weather Data for Record 32 of Set 4 | Port Hardy
# Processing Weather Data for Record 33 of Set 4 | Touho
# City not found....Skipping............
# Processing Weather Data for Record 34 of Set 4 | Nome
# Processing Weather Data for Record 35 of Set 4 | Lagoa Vermelha
# Processing Weather Data for Record 36 of Set 4 | Chicama
# Processing Weather Data for Record 37 of Set 4 | Camaçari
# Processing Weather Data for Record 38 of Set 4 | Minsk
# Processing Weather Data for Record 39 of Set 4 | San Joaquin
# Processing Weather Data for Record 40 of Set 4 | Kitimat
# Processing Weather Data for Record 41 of Set 4 | Ixtapa
# Processing Weather Data for Record 42 of Set 4 | Tezu
# Processing Weather Data for Record 43 of Set 4 | Dunedin
# City not found....Skipping............
# Processing Weather Data for Record 44 of Set 4 | Guilin
# Processing Weather Data for Record 45 of Set 4 | Kyra
# Processing Weather Data for Record 46 of Set 4 | Zalţan
# Processing Weather Data for Record 47 of Set 4 | Talnakh
# Processing Weather Data for Record 48 of Set 4 | Isetskoye
# Processing Weather Data for Record 49 of Set 4 | Port Blair
# Processing Weather Data for Record 50 of Set 4 | Antalaha
# Processing Weather Data for Record 51 of Set 4 | Camacha
# Processing Weather Data for Record 52 of Set 4 | Owo
# City not found....Skipping............
# Processing Weather Data for Record 53 of Set 4 | Barguzin
# Processing Weather Data for Record 54 of Set 4 | Samarai
# Processing Weather Data for Record 55 of Set 4 | Hamilton
# Processing Weather Data for Record 56 of Set 4 | Laas
# Processing Weather Data for Record 57 of Set 4 | Sørland
# Processing Weather Data for Record 58 of Set 4 | Ruteng
# Processing Weather Data for Record 59 of Set 4 | Tabas
# Processing Weather Data for Record 60 of Set 4 | Zimovniki
# Processing Weather Data for Record 61 of Set 4 | Skibbereen
# Processing Weather Data for Record 62 of Set 4 | Pacific Grove
# Processing Weather Data for Record 63 of Set 4 | Province of Brindisi
# Processing Weather Data for Record 64 of Set 4 | Kribi
# Processing Weather Data for Record 65 of Set 4 | Singaraja
# Processing Weather Data for Record 66 of Set 4 | Williams Lake
# Processing Weather Data for Record 67 of Set 4 | Daru
# Processing Weather Data for Record 68 of Set 4 | Tuatapere
# Processing Weather Data for Record 69 of Set 4 | Yishui
# Processing Weather Data for Record 70 of Set 4 | Lodja
# Processing Weather Data for Record 71 of Set 4 | Laurel
# Processing Weather Data for Record 72 of Set 4 | São Lourenço do Sul
# Processing Weather Data for Record 73 of Set 4 | Visby
# Processing Weather Data for Record 74 of Set 4 | Gornopravdinsk
# Processing Weather Data for Record 75 of Set 4 | Romny
# Processing Weather Data for Record 76 of Set 4 | Vikhorevka
# Processing Weather Data for Record 77 of Set 4 | Dakoro
# Processing Weather Data for Record 78 of Set 4 | Buin
# Processing Weather Data for Record 79 of Set 4 | Ventspils
# City not found....Skipping............
# Processing Weather Data for Record 80 of Set 4 | Mapiripán
# Processing Weather Data for Record 81 of Set 4 | Cap-aux-Meules
# Processing Weather Data for Record 82 of Set 4 | Tutóia
# Processing Weather Data for Record 83 of Set 4 | Clyde River
# Processing Weather Data for Record 84 of Set 4 | Havøysund
# Processing Weather Data for Record 85 of Set 4 | Freeport
# Processing Weather Data for Record 86 of Set 4 | Bathsheba
# Processing Weather Data for Record 87 of Set 4 | Sur
# Processing Weather Data for Record 88 of Set 4 | Machiques
# Processing Weather Data for Record 89 of Set 4 | Santa Barbara
# City not found....Skipping............
# Processing Weather Data for Record 90 of Set 4 | Montepuez
# Processing Weather Data for Record 91 of Set 4 | Riyadh
# Processing Weather Data for Record 92 of Set 4 | Bollnäs
# Processing Weather Data for Record 93 of Set 4 | San Rafael
# Processing Weather Data for Record 94 of Set 4 | Moa
# Processing Weather Data for Record 95 of Set 4 | Tonshayevo
# Processing Weather Data for Record 96 of Set 4 | Ingham
# Processing Weather Data for Record 97 of Set 4 | Kaya
# Processing Weather Data for Record 98 of Set 4 | San Carlos
# Processing Weather Data for Record 99 of Set 4 | Shirokiy
# Processing Weather Data for Record 100 of Set 4 | Athabasca
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Weather Data for Record 1 of Set 5 | George Town
# Processing Weather Data for Record 2 of Set 5 | Vangaindrano
# Processing Weather Data for Record 3 of Set 5 | Lata
# Processing Weather Data for Record 4 of Set 5 | Ankang
# Processing Weather Data for Record 5 of Set 5 | Shakiso
# City not found....Skipping............
# Processing Weather Data for Record 6 of Set 5 | Mersing
# Processing Weather Data for Record 7 of Set 5 | Anadyr
# Processing Weather Data for Record 8 of Set 5 | Maridi
# Processing Weather Data for Record 9 of Set 5 | Saint-Joseph
# City not found....Skipping............
# Processing Weather Data for Record 10 of Set 5 | Kerema
# Processing Weather Data for Record 11 of Set 5 | Tateyama
# Processing Weather Data for Record 12 of Set 5 | Nador
# Processing Weather Data for Record 13 of Set 5 | Margate
# Processing Weather Data for Record 14 of Set 5 | Merritt Island
# Processing Weather Data for Record 15 of Set 5 | Omboué
# Processing Weather Data for Record 16 of Set 5 | Yetkul'
# Processing Weather Data for Record 17 of Set 5 | Mandalgovi
# Processing Weather Data for Record 18 of Set 5 | Kokopo
# Processing Weather Data for Record 19 of Set 5 | Ipil
# Processing Weather Data for Record 20 of Set 5 | Chhāgalnāiya
# Processing Weather Data for Record 21 of Set 5 | Jacareacanga
# Processing Weather Data for Record 22 of Set 5 | Kapit
# Processing Weather Data for Record 23 of Set 5 | Norrtälje
# Processing Weather Data for Record 24 of Set 5 | Cartagena
# Processing Weather Data for Record 25 of Set 5 | Zheleznodorozhnyy
# Processing Weather Data for Record 26 of Set 5 | Eureka
# Processing Weather Data for Record 27 of Set 5 | Chivacoa
# Processing Weather Data for Record 28 of Set 5 | Isangel
# City not found....Skipping............
# Processing Weather Data for Record 29 of Set 5 | Kaseda-shirakame
# Processing Weather Data for Record 30 of Set 5 | Chico
# Processing Weather Data for Record 31 of Set 5 | Tura
# Processing Weather Data for Record 32 of Set 5 | Hualmay
# Processing Weather Data for Record 33 of Set 5 | Lac du Bonnet
# Processing Weather Data for Record 34 of Set 5 | Brewster
# Processing Weather Data for Record 35 of Set 5 | Austin
# Processing Weather Data for Record 36 of Set 5 | Samsun Province
# Processing Weather Data for Record 37 of Set 5 | Berdigestyakh
# Processing Weather Data for Record 38 of Set 5 | Nyurba
# Processing Weather Data for Record 39 of Set 5 | Shelburne
# Processing Weather Data for Record 40 of Set 5 | Hobyo
# Processing Weather Data for Record 41 of Set 5 | Vila Velha
# Processing Weather Data for Record 42 of Set 5 | Esim
# Processing Weather Data for Record 43 of Set 5 | Cabo San Lucas
# Processing Weather Data for Record 44 of Set 5 | Maïné Soroa
# Processing Weather Data for Record 45 of Set 5 | Tegul'det
# Processing Weather Data for Record 46 of Set 5 | Mulchén
# Processing Weather Data for Record 47 of Set 5 | Río Gallegos
# Processing Weather Data for Record 48 of Set 5 | Novopokrovka
# Processing Weather Data for Record 49 of Set 5 | Biltine
# Processing Weather Data for Record 50 of Set 5 | Uusikaupunki
# Processing Weather Data for Record 51 of Set 5 | Sosnovka
# Processing Weather Data for Record 52 of Set 5 | Talāja
# Processing Weather Data for Record 53 of Set 5 | Yinchuan
# City not found....Skipping............
# Processing Weather Data for Record 54 of Set 5 | Leningradskiy
# City not found....Skipping............
# Processing Weather Data for Record 55 of Set 5 | Mount Gambier
# Processing Weather Data for Record 56 of Set 5 | Solntsevo
# Processing Weather Data for Record 57 of Set 5 | Pasni
# Processing Weather Data for Record 58 of Set 5 | Sambava
# City not found....Skipping............
# Processing Weather Data for Record 59 of Set 5 | Lorengau
# Processing Weather Data for Record 60 of Set 5 | Qui Nhon
# Processing Weather Data for Record 61 of Set 5 | Kavieng
# Processing Weather Data for Record 62 of Set 5 | Guánica
# Processing Weather Data for Record 63 of Set 5 | Kargasok
# Processing Weather Data for Record 64 of Set 5 | Lábrea
# Processing Weather Data for Record 65 of Set 5 | Teya
# Processing Weather Data for Record 66 of Set 5 | North Platte
# Processing Weather Data for Record 67 of Set 5 | Nicoya
# Processing Weather Data for Record 68 of Set 5 | Kondinskoye
# Processing Weather Data for Record 69 of Set 5 | Yārāda
# Processing Weather Data for Record 70 of Set 5 | Lázaro Cárdenas
# Processing Weather Data for Record 71 of Set 5 | Say
# Processing Weather Data for Record 72 of Set 5 | Dwārka
# Processing Weather Data for Record 73 of Set 5 | Vyborg
# Processing Weather Data for Record 74 of Set 5 | Zhezkazgan
# Processing Weather Data for Record 75 of Set 5 | Talaya
# Processing Weather Data for Record 76 of Set 5 | Altos
# Processing Weather Data for Record 77 of Set 5 | Kushima
# Processing Weather Data for Record 78 of Set 5 | Flin Flon
# Processing Weather Data for Record 79 of Set 5 | Mopipi
# Processing Weather Data for Record 80 of Set 5 | Storebø
# Processing Weather Data for Record 81 of Set 5 | Madera
# City not found....Skipping............
# Processing Weather Data for Record 82 of Set 5 | Chokwé
# City not found....Skipping............
# Processing Weather Data for Record 83 of Set 5 | Quito
# Processing Weather Data for Record 84 of Set 5 | Saint Lawrence
# Processing Weather Data for Record 85 of Set 5 | Sompeta
# Processing Weather Data for Record 86 of Set 5 | Lampa
# Processing Weather Data for Record 87 of Set 5 | Kencong
# Processing Weather Data for Record 88 of Set 5 | Muhafazat Lahij
# Processing Weather Data for Record 89 of Set 5 | Verkhoyansk
# Processing Weather Data for Record 90 of Set 5 | Touros
# Processing Weather Data for Record 91 of Set 5 | Husavik
# Processing Weather Data for Record 92 of Set 5 | Karratha
# Processing Weather Data for Record 93 of Set 5 | Mahina
# Processing Weather Data for Record 94 of Set 5 | Seabra
# Processing Weather Data for Record 95 of Set 5 | Beringovskiy
# Processing Weather Data for Record 96 of Set 5 | Tashigang
# Processing Weather Data for Record 97 of Set 5 | Balyqshy
# Processing Weather Data for Record 98 of Set 5 | Jalingo
# Processing Weather Data for Record 99 of Set 5 | Lincoln
# Processing Weather Data for Record 100 of Set 5 | Half Moon Bay
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Weather Data for Record 1 of Set 6 | Maniitsoq
# Processing Weather Data for Record 2 of Set 6 | Changying
# Processing Weather Data for Record 3 of Set 6 | Oussouye
# Processing Weather Data for Record 4 of Set 6 | Kaka
# Processing Weather Data for Record 5 of Set 6 | Jutaí
# Processing Weather Data for Record 6 of Set 6 | Upata
# Processing Weather Data for Record 7 of Set 6 | Sisimiut
# Processing Weather Data for Record 8 of Set 6 | Makakilo City
# Processing Weather Data for Record 9 of Set 6 | Salé
# Processing Weather Data for Record 10 of Set 6 | Lipari
# Processing Weather Data for Record 11 of Set 6 | Necochea
# Processing Weather Data for Record 12 of Set 6 | Nakamura
# Processing Weather Data for Record 13 of Set 6 | Kavaratti
# Processing Weather Data for Record 14 of Set 6 | Nokaneng
# Processing Weather Data for Record 15 of Set 6 | Alice Springs
# Processing Weather Data for Record 16 of Set 6 | Wattegama
# Processing Weather Data for Record 17 of Set 6 | Tigil'
# Processing Weather Data for Record 18 of Set 6 | La Peca
# Processing Weather Data for Record 19 of Set 6 | Ambon City
# Processing Weather Data for Record 20 of Set 6 | Moanda
# Processing Weather Data for Record 21 of Set 6 | Kysyl-Syr
# Processing Weather Data for Record 22 of Set 6 | Agbor
# Processing Weather Data for Record 23 of Set 6 | Labytnangi
# City not found....Skipping............
# Processing Weather Data for Record 24 of Set 6 | Bud
# Processing Weather Data for Record 25 of Set 6 | Banda Aceh
# Processing Weather Data for Record 26 of Set 6 | Cabedelo
# Processing Weather Data for Record 27 of Set 6 | Pechenga
# Processing Weather Data for Record 28 of Set 6 | Edson
# Processing Weather Data for Record 29 of Set 6 | Pevek
# City not found....Skipping............
# Processing Weather Data for Record 30 of Set 6 | Sokoni
# City not found....Skipping............
# Processing Weather Data for Record 31 of Set 6 | Brae
# Processing Weather Data for Record 32 of Set 6 | Varnavino
# Processing Weather Data for Record 33 of Set 6 | Ulaanbaatar
# Processing Weather Data for Record 34 of Set 6 | Port Moresby
# Processing Weather Data for Record 35 of Set 6 | Nam Som
# Processing Weather Data for Record 36 of Set 6 | Roald
# Processing Weather Data for Record 37 of Set 6 | Aitape
# Processing Weather Data for Record 38 of Set 6 | Christiana
# Processing Weather Data for Record 39 of Set 6 | Newton Stewart
# Processing Weather Data for Record 40 of Set 6 | Torrelavega
# Processing Weather Data for Record 41 of Set 6 | North Bend
# Processing Weather Data for Record 42 of Set 6 | Merrillville
# Processing Weather Data for Record 43 of Set 6 | Petropavlovsk-Kamchatskiy
# Processing Weather Data for Record 44 of Set 6 | Utete
# Processing Weather Data for Record 45 of Set 6 | Chingirlau
# Processing Weather Data for Record 46 of Set 6 | Methóni
# Processing Weather Data for Record 47 of Set 6 | Beloha
# Processing Weather Data for Record 48 of Set 6 | Seoul
# Processing Weather Data for Record 49 of Set 6 | Dekar
# Processing Weather Data for Record 50 of Set 6 | Loukhi
# Processing Weather Data for Record 51 of Set 6 | Rosarito
# Processing Weather Data for Record 52 of Set 6 | Vao
# Processing Weather Data for Record 53 of Set 6 | Ol'ga
# Processing Weather Data for Record 54 of Set 6 | Florø
# Processing Weather Data for Record 55 of Set 6 | San Patricio
# Processing Weather Data for Record 56 of Set 6 | Asău
# Processing Weather Data for Record 57 of Set 6 | Toyota
# Processing Weather Data for Record 58 of Set 6 | Kalanguy
# Processing Weather Data for Record 59 of Set 6 | Vuktyl
# Processing Weather Data for Record 60 of Set 6 | Kahului
# Processing Weather Data for Record 61 of Set 6 | Yekimovichi
# Processing Weather Data for Record 62 of Set 6 | Ko Samui
# Processing Weather Data for Record 63 of Set 6 | Zhuhai
# Processing Weather Data for Record 64 of Set 6 | Saint-François
# Processing Weather Data for Record 65 of Set 6 | Torbay
# Processing Weather Data for Record 66 of Set 6 | Manado
# Processing Weather Data for Record 67 of Set 6 | Gossaigaon
# Processing Weather Data for Record 68 of Set 6 | Sonta
# Processing Weather Data for Record 69 of Set 6 | Varhaug
# Processing Weather Data for Record 70 of Set 6 | Harper
# Processing Weather Data for Record 71 of Set 6 | Krasnoborsk
# Processing Weather Data for Record 72 of Set 6 | Broome
# Processing Weather Data for Record 73 of Set 6 | Laguna
# Processing Weather Data for Record 74 of Set 6 | Dehlorān
# Processing Weather Data for Record 75 of Set 6 | Chiredzi
# Processing Weather Data for Record 76 of Set 6 | Norden
# Processing Weather Data for Record 77 of Set 6 | Zhigalovo
# City not found....Skipping............
# Processing Weather Data for Record 78 of Set 6 | Khandyga
# Processing Weather Data for Record 79 of Set 6 | Dzerzhinskoye
# Processing Weather Data for Record 80 of Set 6 | Llanes
# City not found....Skipping............
# Processing Weather Data for Record 81 of Set 6 | Valença do Piauí
# Processing Weather Data for Record 82 of Set 6 | Lumeje
# Processing Weather Data for Record 83 of Set 6 | Tanabe
# Processing Weather Data for Record 84 of Set 6 | Altamira
# Processing Weather Data for Record 85 of Set 6 | Tautira
# Processing Weather Data for Record 86 of Set 6 | Nuevo Progreso

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#DF set up and clean up
city_weatherDF['Max Temp']  = city_weatherDF['Max Temp'].replace("", np.nan)
city_weatherDF = city_weatherDF.dropna()

#exporting
city_weatherDF.to_csv("../output_data/CityWeather.csv", index=False, header=True)

city_weatherDF.head()
# Out:
#          City Cloudiness        Date Humidity      Lat      Lng  Max Temp  \
# 0   geraldton          0  1610738106       34 -28.7667    114.6     84.20
# 2  sao filipe        100  1610738107       65  14.8961 -24.4956     74.41
# 3     mataura         24  1610738107       91 -46.1927  168.864     56.23
# 4     bumbuna         13  1610738107       21     9.05 -11.7333     79.90
# 5       bluff         93  1610738107       93    -46.6  168.333     56.73
#
#   Windspeed
# 0     26.46
# 2     10.96
# 3      1.66
# 4      1.61
# 5      2.84

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No cities over 100%

# %%
#  Get the indices of cities that have humidity over 100%.
#No Cities over 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_weatherDF['Lat'], city_weatherDF['Max Temp'], marker = "o")

#Plot details
plt.title(f'City Latitude vs. Max Temperature {time.strftime("%m/%d/%Y")}')
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#saving
plt.savefig("../output_data/Lat vs. Max Temp.png")

plt.show()

##This is analyzing the max temperature of each city amongst the latitudes in which they are located. You would hope to find the largest temperatures near 0 latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Plotting
plt.scatter(city_weatherDF['Lat'], city_weatherDF['Humidity'], marker = "o")

#Plot details
plt.title(f'City Latitude vs. Humidity {time.strftime("%m/%d/%Y")}')
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

#saving
plt.savefig("../output_data/Lat vs. Humidity.png")

plt.show()

##This is analyzing the Cities latitude against the Humidity %.  As we go north and south of the equator (0 latitude) we can see if there are any correlations with humidity %.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Plotting
plt.scatter(city_weatherDF['Lat'], city_weatherDF['Cloudiness'], marker = "o")

#Plot details
plt.title(f'City Latitude vs. Cloudiness {time.strftime("%m/%d/%Y")}')
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

#saving
plt.savefig("../output_data/Lat vs. Cloudiness.png")

plt.show()

##This is plotting the cloudiness of each city against the cities latitude.  We can see if latitude effects how cloudiness levels.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Plotting
plt.scatter(city_weatherDF['Lat'], city_weatherDF['Windspeed'], marker = "o")

#Plot details
plt.title(f'City Latitude vs. Windspeed {time.strftime("%m/%d/%Y")}')
plt.ylabel("Windspeed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

#saving
plt.savefig("../output_data/Lat vs. Windspeed.png")

plt.show()

##This is plotting windspeed against latitdue.  We can see if windspeed would be affected based on a cities latitude.

# %% [markdown]
# ## Linear Regression

# %%
#Northern Hemisphere locations
north = city_weatherDF.loc[city_weatherDF["Lat"].astype(float) >= 0.0]
north.reset_index(inplace=True)

#Southern Hemisphere Locations

south = city_weatherDF.loc[city_weatherDF["Lat"].astype(float) < 0.0]
south.reset_index(inplace=True)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north['Lat']).astype(float)
y_values = pd.to_numeric(north['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as latitude increases = temperature decreases.")
plt.savefig("../output_data/Northern Hemisphere Lat vs. Max Temp.png")
plt.show()
# Out:
# Regression line equation is: y = -1.41x + 94.75
# The r-squared is: -0.8522606727125706
# The regression displays a negative correlation.
# In the nothern hemisphere, as latitude increases = temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south['Lat']).astype(float)
y_values = pd.to_numeric(south['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("Southern hemisphere, as latitude approaches 0 = temperature increases.")
plt.savefig("../output_data/Southern Hemisphere Lat vs. Max Temp.png")
plt.show()
# Out:
# Regression line equation is: y = 0.36x + 82.73
# The r-squared is: 0.5138863274727895
# The regression displays a positive correlation.
# Southern hemisphere, as latitude approaches 0 = temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north['Lat']).astype(float)
y_values = pd.to_numeric(north['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a somehwat poor positive correlation.")
print("In the nothern hemisphere, as latitude as latitiude increases there is a somewhat positive correlation with an increase in humidity ")
plt.savefig("../output_data/Northern Hemisphere Lat vs. Humidity.png")
plt.show()
# Out:
# Regression line equation is: y = 0.51x + 52.92
# The r-squared is: 0.4644423088135548
# The regression displays a somehwat poor positive correlation.
# In the nothern hemisphere, as latitude as latitiude increases there is a somewhat positive correlation with an increase in humidity

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south['Lat']).astype(float)
y_values = pd.to_numeric(south['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression is very poor.")
print("There is a very poor positive correlation with humidity as latitude approaches 0 in the Southern Hemisphere.")
plt.savefig("../output_data/Southern Hemisphere Lat vs. Humidity.png")
plt.show()
# Out:
# Regression line equation is: y = 0.25x + 77.86
# The r-squared is: 0.1868818068020983
# The regression is very poor.
# There is a very poor positive correlation with humidity as latitude approaches 0 in the Southern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north['Lat']).astype(float)
y_values = pd.to_numeric(north['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a poor correlation.")
print("In the nothern hemisphere, as latitude increases there is a poor positive correlation with an increase in cloudiness")
plt.savefig("../output_data/Northern Hemisphere Lat vs. Cloudiness.png")
plt.show()
# Out:
# Regression line equation is: y = 0.7x + 26.86
# The r-squared is: 0.34115043058570826
# The regression displays a poor correlation.
# In the nothern hemisphere, as latitude increases there is a poor positive correlation with an increase in cloudiness

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south['Lat']).astype(float)
y_values = pd.to_numeric(south['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a poor correlation")
print("Southern hemisphere, as latitude approaches 0 cloudiness has a poor positive correlation.")
plt.savefig("../output_data/Southern Hemisphere Lat vs. Cloudiness.png")
plt.show()
# Out:
# Regression line equation is: y = 0.6x + 71.88
# The r-squared is: 0.22019746215738892
# The regression displays a poor correlation
# Southern hemisphere, as latitude approaches 0 cloudiness has a poor positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(north['Lat']).astype(float)
y_values = pd.to_numeric(north['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Windspeed (mph)')
plt.title('Northern Hemisphere - Windspeed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a poor correlation.")
print("In the nothern hemisphere, there is a poor correlation with Wyuindspeed vs. Latitude")
plt.savefig("../output_data/Northern Hemisphere Lat vs. Windspeed.png")
plt.show()
# Out:
# Regression line equation is: y = 0.02x + 7.11
# The r-squared is: 0.055256902815119635
# The regression displays a poor correlation.
# In the nothern hemisphere, there is a poor correlation with Wyuindspeed vs. Latitude

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(south['Lat']).astype(float)
y_values = pd.to_numeric(south['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Windspeed (mph)')
plt.title('Southern Hemisphere - Windspeed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a poor correlation.")
print("Southern hemisphere, there is a poor correlation with windspeed and latitude.")
plt.savefig("../output_data/Southern Hemisphere Lat vs. Windspeed.png")
plt.show()
# Out:
# Regression line equation is: y = -0.08x + 7.15
# The r-squared is: -0.2047089096271659
# The regression displays a poor correlation.
# Southern hemisphere, there is a poor correlation with windspeed and latitude.
